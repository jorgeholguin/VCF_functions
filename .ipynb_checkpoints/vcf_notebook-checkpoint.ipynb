# %% [markdown]
# # VCF_functions.py
#
# A framework to process variant call files (VCF) and mutation annotation files (MAF) into pandas dataframes. Able to retrieve mutations for proteins of interest using their Ensembl Transcript identifiers.

# %%
import pandas as pd
import VCF_functions as vcf

# %% [markdown]
# ## Process a VCF file

# %% [markdown]
# ### Without specifying a list of transcript ids

# %%
df_vcf = vcf.read_process_vcf('./data/vcf_data/a/a.vcf', 'missense_variant', 'SNV', return_case_id=False)

# %%
df_vcf
# Out:
#   CHROM   POS ID REF ALT QUAL FILTER  \
# 0  chr7  1111  .   X   Y    .   PASS
#
#                                                 INFO FORMAT NORMAL TUMOR
# 0  {'ACGTNacgtnMINUS': '0', 'ACGTNacgtnPLUS': '0'...      X      Y     Z

# %% [markdown]
# ### With a list of specified transcript ids, the information in the `INFO` column for that transcript is expanded and added to the dataframe

# %%
ids = ['ENST00000318560']
df_vcf = vcf.read_process_vcf('./data/vcf_data/a/a.vcf', 'missense_variant', 'SNV', return_case_id=False, 
                              id_list = ids)

# %%
df_vcf
# Out:
#   CHROM   POS ID REF ALT QUAL FILTER  \
# 0  chr7  1111  .   X   Y    .   PASS
#
#                                                 INFO FORMAT NORMAL  ...  \
# 0  {'ACGTNacgtnMINUS': '0', 'ACGTNacgtnPLUS': '0'...      X      Y  ...
#
#   CLIN_SIG SOMATIC PHENO PUBMED MOTIF_NAME MOTIF_POS HIGH_INF_POS  \
# 0
#
#   MOTIF_SCORE_CHANGE ENTREZ EVIDENCE
# 0                      5243
#
# [1 rows x 77 columns]

# %%
df_vcf[['Consequence', 'IMPACT', 'SYMBOL', 'Gene',
       'Feature_type', 'Feature', 'BIOTYPE', 'EXON', 'INTRON', 'HGVSc',
       'HGVSp', 'cDNA_position', 'CDS_position', 'Protein_position',
       'Amino_acids']]
# Out:
#         Consequence    IMPACT SYMBOL             Gene Feature_type  \
# 0  missense_variant  MODERATE   ABL1  ENSG00000085563   Transcript
#
#            Feature         BIOTYPE    EXON INTRON  \
# 0  ENST00000318560  protein_coding  1/1130
#
#                          HGVSc                          HGVSp cDNA_position  \
# 0  ENST00000622132.3:c.2428A>G  ENSP00000478255.1:p.Thr810Ala     2753/4778
#
#   CDS_position Protein_position Amino_acids
# 0    2428/3843           1/1130         T/A

# %% [markdown]
# ## Process a MAF file

# %% [markdown]
# ### Without specifying a list of transcript ids

# %%
df_maf = vcf.read_process_maf('./data/maf_data/a.maf', variant='Missense_Mutation', consequence='missense_variant', 
                              variant_class='SNP')

# %%
df_maf.head(2)
# Out:
#   Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 1      ATPAF1           64756  WUGSC     GRCh38       chr1        46665282
# 2        RORC            6097  WUGSC     GRCh38       chr1       151814660
#
#    End_Position Strand Variant_Classification Variant_Type  ...  \
# 1      46665282      +      Missense_Mutation          SNP  ...
# 2     151814660      +      Missense_Mutation          SNP  ...
#
#                         normal_bam_uuid                               case_id  \
# 1  d4d55edf-e3ee-4b91-8b03-87afdf9bfb5a  bfd49783-1767-469b-9d79-7822301c5efc
# 2  d4d55edf-e3ee-4b91-8b03-87afdf9bfb5a  bfd49783-1767-469b-9d79-7822301c5efc
#
#   GDC_FILTER                  COSMIC  hotspot RNA_Support RNA_depth  \
# 1        NaN              COSM426393        N     Unknown       NaN
# 2        NaN  COSM423839;COSM4813058        N     Unknown       NaN
#
#    RNA_ref_count  RNA_alt_count                callers
# 1            NaN            NaN  muse;mutect2;varscan2
# 2            NaN            NaN  muse;mutect2;varscan2
#
# [2 rows x 140 columns]

# %% [markdown]
# The filtering is done on the `all_effects` column, there may be some variants reported as Silent for the canonical transcript but they are missense for an alternative transcript, those cases are kept

# %% [markdown]
# ### With a list of specified transcript ids, the information in the `all_effects` column for that transcript is expanded and added to the dataframe

# %%
ids = ['ENST00000574428', 'ENST00000318247']
df_maf = vcf.read_process_maf('./data/maf_data/a.maf', variant='Missense_Mutation', consequence='missense_variant', 
                              variant_class='SNP', id_list=ids)

# %%
df_maf
# Out:
#   Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 0      ATPAF1           64756  WUGSC     GRCh38       chr1        46665282
# 1        RORC            6097  WUGSC     GRCh38       chr1       151814660
#
#    End_Position Strand Variant_Classification Variant_Type  ...  \
# 0      46665282      +      Missense_Mutation          SNP  ...
# 1     151814660      +      Missense_Mutation          SNP  ...
#
#   Consequence_all_effects HGVSp_Short_all_effects Transcript_ID_all_effects  \
# 0        missense_variant                 p.D117N           ENST00000574428
# 1        missense_variant                 p.E283K           ENST00000318247
#
#   RefSeq_all_effects  HGVSc_all_effects Impact_all_effects  \
# 0                              c.349G>A           MODERATE
# 1        NM_005060.4           c.847G>A           MODERATE
#
#   Canonical_all_effects   Sift_all_effects      PolyPhen_all_effects  \
# 0                        deleterious(0.05)  possibly_damaging(0.834)
# 1                   YES     deleterious(0)             benign(0.036)
#
#    Strand_all_effects
# 0                  -1
# 1                  -1
#
# [2 rows x 151 columns]

# %% [markdown]
# When a list of transcript IDs is provided, the data in the `all_effects` column is expanded and added to the dataframe. All the columns coming from the `all_effects` column have '_all_effects' at the end.
